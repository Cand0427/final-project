# %% [markdown]
# # HR Analytics challenge

# %% [markdown]
# #### Source :
# https://datahack.analyticsvidhya.com/contest/wns-analytics-hackathon-2018-1/#About

# %% [markdown]
# #### Problem :
# - How to identify the employees that are most likely to be promoted?
# - What characteristics do they have in common?
# - What levers can be used to improve the internal promotion process?

# %% [markdown]
# #### Evaluation metric (as given per the competition) :
# F1 score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ## Dataset exploration

# %%
hr_train = pd.read_csv('C:/Users/user/Documents/02 - FORMATION/Iron Hack - Data Analysis/Module 3/Bootcamp final project/train_LZdllcl.csv')

# %%
hr_test = pd.read_csv('C:/Users/user/Documents/02 - FORMATION/Iron Hack - Data Analysis/Module 3/Bootcamp final project/test_2umaH9m.csv')

# %%
hr_train.info()

#14 columns (13 when removing "employee_id"), 54808 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
hr_train.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
#chose to drop employee_id

hr_train.drop('employee_id', axis=1, inplace=True)
hr_test.drop('employee_id', axis=1, inplace=True)

# %%
hr_test.info()

#13 columns (12 when removing "employee_id"), 23490 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            23490 non-null  object
#  1   region                23490 non-null  object
#  2   education             22456 non-null  object
#  3   gender                23490 non-null  object
#  4   recruitment_channel   23490 non-null  object
#  5   no_of_trainings       23490 non-null  int64
#  6   age                   23490 non-null  int64
#  7   previous_year_rating  21678 non-null  float64
#  8   length_of_service     23490 non-null  int64
#  9   KPIs_met >80%         23490 non-null  int64
#  10  awards_won?           23490 non-null  int64
#  11  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# ### > Codebook

# %%
codebook = pd.DataFrame(index=hr_train.columns, columns=['Type', 'Definition', 'Expected influence', 'Distribution', 'Outliers'])

# %%
codebook
# Out:
#                      Type Definition Expected influence Distribution Outliers
# department            NaN        NaN                NaN          NaN      NaN
# region                NaN        NaN                NaN          NaN      NaN
# education             NaN        NaN                NaN          NaN      NaN
# gender                NaN        NaN                NaN          NaN      NaN
# recruitment_channel   NaN        NaN                NaN          NaN      NaN
# no_of_trainings       NaN        NaN                NaN          NaN      NaN
# age                   NaN        NaN                NaN          NaN      NaN
# previous_year_rating  NaN        NaN                NaN          NaN      NaN
# length_of_service     NaN        NaN                NaN          NaN      NaN
# KPIs_met >80%         NaN        NaN                NaN          NaN      NaN
# awards_won?           NaN        NaN                NaN          NaN      NaN
# ...

# %%
type_hr = {'Categorical' : ['department', 'region', 'education', 'recruitment_channel'], 'Categorical/Ordinal' : ['previous_year_rating'],
           'Categorical/Binary' : ['gender', 'is_promoted', 'KPIs_met >80%', 'awards_won?'], 
           'Numerical' : ['no_of_trainings', 'age', 'length_of_service', 'avg_training_score']}

for k,v in type_hr.items():
    codebook.at[v, 'Type'] = k

# %%
codebook.loc['department','Definition'] = "Department of employee : Sales & Marketing, Operations, Procurement, Technology, Analytics, Finance, HR, Legal, R&D"
codebook.loc['region','Definition'] = "Region of employment"
codebook.loc['education','Definition'] = "Education Level : Bachelor, Master & above, Below Secondary"
codebook.loc['gender','Definition'] = "Employee's gender : m if man, f if woman"
codebook.loc['recruitment_channel','Definition'] = "Channel of recruitment for employee : sourcing, reffered/refferal, other" 
codebook.loc['no_of_trainings','Definition'] = "Number of trainings completed in previous year on soft skills, technical skills etc."
codebook.loc['age','Definition'] = "Employee's age"
codebook.loc['previous_year_rating','Definition'] = "Employee's performance : rating for the previous year, between 1.0 (low) to 5.0 (high)"
codebook.loc['length_of_service','Definition'] = "Length of service in years"
codebook.loc['KPIs_met >80%','Definition'] = "Employee's performance : if percent of achievement of their KPIs > 80% then 1, else 0"
codebook.loc['awards_won?','Definition'] = "Employee's performance : if awards won during previous year then 1, else 0"
codebook.loc['avg_training_score','Definition'] = "Average obtained score over 100 in current training evaluations"
codebook.loc['is_promoted','Definition'] = "(Target) Recommended for promotion : if promoted then 1, else 0"

# %%
influence_hr = {'+ (low)' : ['region', 'gender', 'no_of_trainings'], 
           '++ (medium)' : ['department', 'education', 'recruitment_channel', 'age', 'length_of_service'], 
           '+++ (high)' : ['previous_year_rating', 'KPIs_met >80%', 'awards_won?', 'avg_training_score'],
               '(Target) N/A' : ['is_promoted']}

for k,v in influence_hr.items():
    codebook.at[v, 'Expected influence'] = k

# %% [markdown]
# ### > Checking for missing values

# %%
hr_train.isna().sum()
# Out:
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %% [markdown]
# #### >> Investigating null values in "education"

# %%
# creating bool series True for NaN values  
null_education = pd.isnull(hr_train["education"])  
    
# filtering data  
# displaying data only with "education" = NaN  
hr_train[null_education]
# Out:
#               department     region education gender recruitment_channel  \
# 10            Technology  region_23       NaN      m            sourcing
# 21            Operations  region_15       NaN      m            sourcing
# 32     Sales & Marketing   region_7       NaN      f            sourcing
# 43     Sales & Marketing   region_2       NaN      m               other
# 82     Sales & Marketing   region_2       NaN      m            sourcing
# ...                  ...        ...       ...    ...                 ...
# 54692  Sales & Marketing   region_2       NaN      f            sourcing
# 54717          Analytics   region_2       NaN      m            sourcing
# 54729                 HR   region_2       NaN      f               other
# 54742  Sales & Marketing  region_31       NaN      m               other
# 54806  Sales & Marketing   region_9       NaN      m            sourcing
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# ...

# %%
2409/54808

#below 10% 

#option 1 : we won't delete these NaN values but will replace them by the most common value : Bachelor's

#option 2 : by other categories available (following the current feature's distribution)
# Out:
# 0.04395343745438622

# %%
hr_train['education'].value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
hr_train['education'].fillna("Bachelor's", inplace=True)

# %%
#à revoir plus tard
#créer un subset de valeurs non nulles et remplacer valeurs manquantes par valeurs de la colonne education sur ce subset

import random

random.sample(set(hr_train), 2409)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2eef78f011f7> in <module>
#       4 import random
#       5
# ----> 6 random.sample(set(hr_train), 2409)
#
# ~\anaconda3\lib\random.py in sample(self, population, k)
#     319         n = len(population)
#     320         if not 0 <= k <= n:
# --> 321             raise ValueError("Sample larger than population or is negative")
#     322         result = [None] * k
#     323         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
hr_train.isna().sum()
# Out:
# department                 0
# region                     0
# education                  0
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %% [markdown]
# #### >> Investigating null values in "previous_year_rating"

# %%
# creating bool series True for NaN values  
null_rating = pd.isnull(hr_train["previous_year_rating"])  
    
# filtering data  
# displaying data only with "previous_year_rating" = NaN  
hr_train[null_rating]
# Out:
#               department     region   education gender recruitment_channel  \
# 10            Technology  region_23  Bachelor's      m            sourcing
# 23           Procurement   region_5  Bachelor's      m               other
# 29     Sales & Marketing   region_4  Bachelor's      m            sourcing
# 56     Sales & Marketing  region_31  Bachelor's      f               other
# 58     Sales & Marketing  region_16  Bachelor's      m               other
# ...                  ...        ...         ...    ...                 ...
# 54703                R&D  region_31  Bachelor's      m            sourcing
# 54734         Operations  region_15  Bachelor's      m            sourcing
# 54746            Finance   region_6  Bachelor's      m               other
# 54773            Finance   region_2  Bachelor's      m               other
# 54801         Technology  region_26  Bachelor's      f            sourcing
#
# ...

# %%
hr_train[hr_train["previous_year_rating"].isnull()]['length_of_service'].value_counts()

#all missing values in "previous_year_rating" are coming from employees with 1 year of seniority (maybe actually a bit less ?) : it seems normal they did not have a proper evaluation yet
# Out:
# 1    4124
# Name: length_of_service, dtype: int64

# %%
4124/54808

#below 10%
# Out:
# 0.07524448985549555

# %%
hr_train.dropna(subset=['previous_year_rating'], inplace=True)

# %%
hr_train.isna().sum()
# Out:
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %% [markdown]
# ### > Checking for outliers

# %%
hr_train.shape
# Out:
# (50684, 13)

# %%
hr_train.describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     50684.000000  50684.000000          50684.000000       50684.000000
# mean          1.248362     35.449195              3.329256           6.261404
# std           0.600226      7.570842              1.259993           4.193831
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     30.000000              3.000000           3.000000
# 50%           1.000000     34.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           8.000000
# max          10.000000     60.000000              5.000000          37.000000
#
#        KPIs_met >80%   awards_won?  avg_training_score   is_promoted
# count   50684.000000  50684.000000        50684.000000  50684.000000
# mean        0.352162      0.023163           63.389137      0.085412
# ...

# %%
sns.boxplot(hr_train['no_of_trainings'])
plt.title('Boxplot view of nb of trainings')
plt.xlabel('Nb of trainings')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Nb of trainings')

# %%
sns.boxplot(hr_train['age'])
plt.title('Boxplot view of age')
plt.xlabel('Ages')

#mean = 34 : 50% of employees have less/more than 34 years old
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Ages')

# %%
sns.boxplot(hr_train['previous_year_rating'])
plt.title('Boxplot view of performance rating of previous year')
plt.xlabel('Rating scores out of 5')

#mean = 3 : 50% of employees got a previous year rating score below/above 3 (out of 5)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Rating scores out of 5')

# %%
sns.boxplot(hr_train['length_of_service'])
plt.title('Boxplot view of length of service')
plt.xlabel('Number of years')


#mean = 5 : 50% of employees have been working in the company for less/more than 5 years
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Number of years')

# %%
sns.boxplot(hr_train['avg_training_score'])
plt.title('Boxplot view of average training scores')
plt.xlabel('Average training scores')

#mean = 60 : 50% of employees have an average training score below/above 60 (out of 100)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Average training scores')

# %% [markdown]
# ### > Univaried analysis : checking distributions of variables (#to do : update codebook)

# %% [markdown]
# #### >> Numerical features

# %%
sns.distplot(hr_train['no_of_trainings'])
plt.title("Number of trainings completed in previous year")
plt.xlabel('Number of trainings')

#hr_train['no_of_trainings'].hist()
             
#long-tail
#right-skewed (to be checked)

#most employees follow between 1 and 2 trainings per year
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Number of trainings')

# %%
import math

#hr_train['no_of_trainings'].apply(math.sqrt).hist()

#np.log plus puissant que math.sqrt()
#est-ce qu'il faut assigner hr_train['no_of_trainings'] = hr_train['no_of_trainings'].apply(np.log OU math.sqrt) ? => nvelle colonne
#transfo pas très pertinente

# %%
#comparaison avec np.log

#sns.distplot(hr_train['no_of_trainings'].apply(np.log), bins=100)

#transfo pas très pertinente

# %%
sns.distplot(hr_train['age'], bins=30)
plt.title("Age distribution")
plt.xlabel('Ages')

#hr_train['age'].hist()

#right-skewed (to be checked)

#most employees are in their thirties
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Ages')

# %%
sns.distplot(hr_train['length_of_service'])
plt.title("Length of service")
plt.xlabel('Number of years')

#hr_train['length_of_service'].hist()

#long-tail
#right-skewed (to be checked)

#most employees have less than 5 years of seniority in the company
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Number of years')

# %%
hr_train['length_of_service'].apply(math.sqrt).hist()
plt.title("Length of service (after square root transformation)")
plt.xlabel('Number of years')
# Out:
# Text(0.5, 0, 'Number of years')

# %%
from scipy.stats import skew
print(skew(hr_train['length_of_service'].apply(np.log)))

#donne score de skewness => pour déterminer degré de symétrie
# 0 : très symétrique
# un peu trop sur la droite +
# un peu trop sur la gauche -
#intérêt d'utiliser skew = confirmer aperçu graphique
# Out:
# 0.060428621795654315

# %%
#comparaison avec np.log
sns.distplot(hr_train['length_of_service'].apply(np.log), bins=20)
plt.title("Length of service in years (after log transformation)")
plt.xlabel("Number of years")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Number of years')

# %%
#sns.kdeplot(data=hr_train, x="length_of_service", log_scale=True)

# %%
sns.distplot(hr_train['avg_training_score'], bins=20)
plt.title("Average scores obtained by employees (out of 100) in current training evaluations")
plt.xlabel('Average training scores')

#hr_train['avg_training_score'].hist(bins=30)

#most employees got a training score between 50-60%
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Average training scores')

# %% [markdown]
# #### >> Categorical features

# %%
ax = sns.countplot(x=hr_train["department"], data=hr_train, order=hr_train["department"].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.title('Employee headcount by department')
plt.xlabel("Company's departments")

#top 3 departments (in headcount) are Sales & Marketing, Operations and Procurement
# Out:
# Text(0.5, 0, "Company's departments")

# %%
hr_train["department"].value_counts().index
# Out:
# Index(['Sales & Marketing', 'Operations', 'Procurement', 'Technology',
#        'Analytics', 'Finance', 'HR', 'R&D', 'Legal'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.title('Employee distribution per department in %')
plt.xlabel("Company's departments")
#plt.ylabel('xx')

ax = (hr_train['department'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e', '#0eb906', '#d40737', '#9408f5', '#302d28', '#ed96e1', '#b9df26'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
plt.figure(figsize=(12,7))
ax2 = sns.countplot(x=hr_train["region"], data=hr_train, order=hr_train["region"].value_counts().index)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
plt.title('Employee headcount by region')
plt.xlabel('Regions')

#top 3 regions (in headcount) are region_2, region_22 and region_7
# Out:
# Text(0.5, 0, 'Regions')

# %%
plt.figure(figsize=(14,7))
plt.title('Employee distribution by region in %')
plt.xlabel('Regions')
#plt.ylabel('xx')

ax = (hr_train['region'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1), rotation=90)

# %%
ax3 = sns.countplot(x="education", data=hr_train, order=hr_train["education"].value_counts().index)
#ax3.set_xticklabels(ax3.get_xticklabels(), rotation=60)
plt.title("Employee headcount by level of education")
plt.xlabel('Degrees')

#most employees have a Bachelor degree
# Out:
# Text(0.5, 0, 'Degrees')

# %%
plt.title("Employees' levels of education distribution in %")
plt.xlabel('Degrees')
#plt.ylabel('xx')

ax = (hr_train['education'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e', '#0eb906'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x="gender", data=hr_train)
plt.title("Gender distribution")
plt.xlabel('Gender')

#there are more men than women working in this company
# Out:
# Text(0.5, 0, 'Gender')

# %%
plt.title('Gender distribution in %')
plt.xlabel('Gender')
#plt.ylabel('xx')

ax = (hr_train['gender'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x="recruitment_channel", data=hr_train, order=hr_train["recruitment_channel"].value_counts().index)
plt.title("Headcount by recruitment source")
plt.xlabel('Recruitment channels')

#most employees were recruited by "another" channel than classical sourcing or referral system
# Out:
# Text(0.5, 0, 'Recruitment channels')

# %%
plt.title('Recruitment sources distribution in %')
plt.xlabel('Recruitment channels')
#plt.ylabel('xx')

ax = (hr_train['recruitment_channel'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e', '#0eb906'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x='previous_year_rating', data=hr_train)
plt.title("Employee's performance : previous year ratings")
plt.xlabel('Scores (out of 5)')

#most employees got an average score (3/5) at their performance evaluation for previous year
# Out:
# Text(0.5, 0, 'Scores (out of 5)')

# %%
plt.title('Average rating scores for the previous year in %')
plt.xlabel('Scores (out of 5)')
#plt.ylabel('xx')

ax = (hr_train['previous_year_rating'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e', '#0eb906', '#d40737', '#9408f5'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x='KPIs_met >80%', data=hr_train)
plt.title("Employee's performance : achievement of KPIs > 80%")
plt.xlabel('0 : not achieved, 1 : achieved')

#most employees did not complete >80% of their KPIs in the previous year
# Out:
# Text(0.5, 0, '0 : not achieved, 1 : achieved')

# %%
plt.title('Proportion of employees who completed >80% of their KPIs')
plt.xlabel('0 : not achieved, 1 : achieved')
#plt.ylabel('xx')

ax = (hr_train['KPIs_met >80%'].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x='awards_won?', data=hr_train)
plt.title("Employee's performance : employees who won awards during previous year")
plt.xlabel('0 : no award won, 1 : award won')

#most employees did not receive awards in the previous year
# Out:
# Text(0.5, 0, '0 : no award won, 1 : award won')

# %%
plt.title('Proportion of employees who won an award')
plt.xlabel('0 : no award won, 1 : award won')
#plt.ylabel('xx')

ax = (hr_train["awards_won?"].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x="is_promoted", data=hr_train)
plt.title("Employee headcount per promotion status")
plt.xlabel('0 : not promoted, 1 : promoted')

#most employees did not receive a promotion
# Out:
# Text(0.5, 0, '0 : not promoted, 1 : promoted')

# %%
plt.title('Proportion of employees who are promoted')
plt.xlabel('0 : not promoted, 1 : promoted')
#plt.ylabel('xx')

ax = (hr_train["is_promoted"].value_counts()/len(hr_train)*100).sort_index().plot(kind="bar", rot=0, color=['#3406cb', '#f9b13e'])

ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(hr_train)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %% [markdown]
# #### Summary - univaried analysis :
#
# ##### NUMERICAL FEATURES
#
# - no_of_trainings : most employees follow between 1 and 2 trainings per year
# - age : most employees are in their 30ies
# - length_of_service : most employees have less than 5 years of seniority in the company
# - avg_training_score : most employees got an average training score between 50-60%
#
#
# ##### CATEGORICAL FEATURES
#
# - department : top 3 departments (in headcount) are Sales & Marketing, Operations and Procurement
# - region : top 3 regions (in headcount) are region_2, region_22 and region_7
# - education : most employees have a Bachelor degree
# - recruitement_channel : most employees were recruited by "another" channel than classical sourcing or referral system
#
# ####### CATEGORICAL BINARY
# - gender : there are more men than women working in this company
# - KPIs_met >80% : most employees did not complete >80% of their KPIs in the previous year
# - awards_won? : most employees did not receive awards in the previous year
# - is_promoted : most employees did not receive a promotion
#
# ####### CATEGORICAL ORDINAL
# - previous_year_rating : most employees got an average score (3/5) at their performance evaluation for previous year

# %% [markdown]
# ### > Multivaried analysis - versus target feature (1/2)

# %% [markdown]
# #### >> Numerical features

# %% [markdown]
# ##### >>> Nb of trainings x Is promoted

# %%
hr_train[hr_train['is_promoted'] == 0]['no_of_trainings'].mean()
# Out:
# 1.2528961277100636

# %%
hr_train[hr_train['is_promoted'] == 1]['no_of_trainings'].mean()
# Out:
# 1.1998151998151998

# %%
plt.figure(figsize=(8,4))
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['no_of_trainings'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['no_of_trainings'], shade=True, color="r")

#les distributions se superposent : pas de corrélation a priori
# Out:
# <AxesSubplot:xlabel='no_of_trainings', ylabel='Density'>

# %% [markdown]
# ##### >>> Age x Is promoted

# %%
hr_train[hr_train['is_promoted'] == 0]['age'].mean()
# Out:
# 35.49668859885665

# %%
hr_train[hr_train['is_promoted'] == 1]['age'].mean()
# Out:
# 34.94063294063294

# %%
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['age'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['age'], shade=True, color="r")

#les distributions se superposent : pas de corrélation a priori
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ##### >>> Length of service x Is promoted

# %%
hr_train[hr_train['is_promoted'] == 0]['length_of_service'].mean()
# Out:
# 6.277812533707259

# %%
hr_train[hr_train['is_promoted'] == 1]['length_of_service'].mean()
# Out:
# 6.085701085701086

# %%
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['length_of_service'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['length_of_service'], shade=True, color="r")

#les distributions se superposent : pas de corrélation a priori
# Out:
# <AxesSubplot:xlabel='length_of_service', ylabel='Density'>

# %% [markdown]
# ##### >>> Average training score x Is promoted

# %%
hr_train[hr_train['is_promoted'] == 0]['avg_training_score'].mean()
# Out:
# 62.65242152950059

# %%
hr_train[hr_train['is_promoted'] == 1]['avg_training_score'].mean()
# Out:
# 71.27789327789328

# %%
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['avg_training_score'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['avg_training_score'], shade=True, color="r")

#les distributions ne se superposent pas : corrélation à vérifier avec Pearson
# Out:
# <AxesSubplot:xlabel='avg_training_score', ylabel='Density'>

# %% [markdown]
# ##### >>> Pearson correlation table

# %%
plt.figure(figsize=(10,8))
mask = np.triu(np.ones_like(hr_train.corr(), dtype=np.bool))
sns.heatmap(hr_train.corr(), cmap="YlGnBu", annot=True, square=True, mask=mask, vmin=-1, vmax=1)

#avg_training_score x is_promoted : corr = 0.18 : faible cf. https://fr.wikipedia.org/wiki/Corr%C3%A9lation_(statistiques) "Interprétation"
# Out:
# <AxesSubplot:>

# %%
#test corrélation non-linéaire
hr_train.corr(method ='kendall')
# Out:
#                       no_of_trainings       age  previous_year_rating  \
# no_of_trainings              1.000000 -0.072364             -0.051875
# age                         -0.072364  1.000000              0.008358
# previous_year_rating        -0.051875  0.008358              1.000000
# length_of_service           -0.046101  0.452057              0.002155
# KPIs_met >80%               -0.039281 -0.017825              0.326307
# awards_won?                 -0.007959 -0.007608              0.025419
# avg_training_score           0.043627 -0.036825              0.057184
# is_promoted                 -0.021924 -0.012454              0.143582
#
#                       length_of_service  KPIs_met >80%  awards_won?  \
# no_of_trainings               -0.046101      -0.039281    -0.007959
# age                            0.452057      -0.017825    -0.007608
# previous_year_rating           0.002155       0.326307     0.025419
# ...

# %%
#test corrélation non-linéaire
hr_train.corr(method = 'spearman')
# Out:
#                       no_of_trainings       age  previous_year_rating  \
# no_of_trainings              1.000000 -0.088093             -0.058165
# age                         -0.088093  1.000000              0.011070
# previous_year_rating        -0.058165  0.011070              1.000000
# length_of_service           -0.054846  0.580056              0.002770
# KPIs_met >80%               -0.039974 -0.021374              0.359579
# awards_won?                 -0.008100 -0.009123              0.028011
# avg_training_score           0.053696 -0.053053              0.076806
# is_promoted                 -0.022311 -0.014933              0.158222
#
#                       length_of_service  KPIs_met >80%  awards_won?  \
# no_of_trainings               -0.054846      -0.039974    -0.008100
# age                            0.580056      -0.021374    -0.009123
# previous_year_rating           0.002770       0.359579     0.028011
# ...

# %%
#Rappels :
#cat x cat => Cramer test
#cat x num => boxplot ou autre
#num x num => corr table

# %% [markdown]
# #### >> Categorical features

# %%
#test de cramer

import scipy.stats as ss

def cramers_v(confusion_matrix):
    """ calculate Cramers V statistic for categorial-categorial association.
        uses correction from Bergsma and Wicher,
        Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

#si résultat proche de 0, pas de corrélation
#si résultat proche de 1, corrélation

# %% [markdown]
# ##### >>> Department x Is promoted

# %%
plt.figure(figsize=(10,5))
ax3 = sns.countplot(x="department", hue="is_promoted", data=hr_train, order=hr_train["department"].value_counts().index)
ax3.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-249012829d14> in <module>
#       1 plt.figure(figsize=(10,5))
#       2 ax3 = sns.countplot(x="department", hue="is_promoted", data=hr_train, order=hr_train["department"].value_counts().index)
# ----> 3 ax3.set_xticklabels(ax.get_xticklabels(), rotation=90)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
# ...

# %%
confusion_matrix = pd.crosstab(hr_train["department"], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#close to 0, no correlation
# Out:
# 0.051567036135843215

# %%
dep_crosstab = pd.crosstab(hr_train["department"], hr_train["is_promoted"], normalize='index')
dep_crosstab['idx'] = dep_crosstab[1]/dep_crosstab[1].mean()*100

plt.figure(figsize=(10,8))
sns.heatmap(dep_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#Departments for which promotion rate is above the mean are, by descending order, Technology, Procurement, Analytics, Operations and Finance
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='department'>

# %% [markdown]
# ##### >>> Region x Is promoted

# %%
plt.figure(figsize=(15,7))
ax4 = sns.countplot(x="region", hue="is_promoted", data=hr_train, order=hr_train["region"].value_counts().index)
ax4.set_xticklabels(ax2.get_xticklabels(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-acf5fad77096> in <module>
#       1 plt.figure(figsize=(15,7))
#       2 ax4 = sns.countplot(x="region", hue="is_promoted", data=hr_train, order=hr_train["region"].value_counts().index)
# ----> 3 ax4.set_xticklabels(ax2.get_xticklabels(), rotation=90)
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
# ...

# %%
confusion_matrix = pd.crosstab(hr_train["region"], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#close to 10% : moderate
# Out:
# 0.09026242689300758

# %%
reg_crosstab = pd.crosstab(hr_train["region"], hr_train["is_promoted"], normalize='index')
reg_crosstab['idx'] = reg_crosstab[1]/reg_crosstab[1].mean()*100

plt.figure(figsize=(25,25))
sns.heatmap(reg_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#Regions for which promotion rate is above the mean are, by decreasing order, 4, 17, 25, 28, 23, 22, 3, 7, 1, 8, 13, 30, 2, 10, 27, 15
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='region'>

# %% [markdown]
# ##### >>> Education x Is promoted

# %%
sns.countplot(x="education", hue="is_promoted", data=hr_train, order=hr_train["education"].value_counts().index)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
confusion_matrix = pd.crosstab(hr_train["education"], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#close to 0, no correlation
# Out:
# 0.030267781948830057

# %%
ed_crosstab = pd.crosstab(hr_train["education"], hr_train["is_promoted"], normalize='index')
ed_crosstab['idx'] = ed_crosstab[1]/ed_crosstab[1].mean()*100

sns.heatmap(ed_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#Employees with Master's degrees (and above) are more likely to be promoted than other categories
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='education'>

# %% [markdown]
# ##### >>> Recruitement channel x Is promoted

# %%
sns.countplot(x="recruitment_channel", hue="is_promoted", data=hr_train, order=hr_train["recruitment_channel"].value_counts().index)
# Out:
# <AxesSubplot:xlabel='recruitment_channel', ylabel='count'>

# %%
confusion_matrix = pd.crosstab(hr_train["recruitment_channel"], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#close to 0, no correlation
# Out:
# 0.020463210236295402

# %%
rec_crosstab = pd.crosstab(hr_train["recruitment_channel"], hr_train["is_promoted"], normalize='index')
rec_crosstab['idx'] = rec_crosstab[1]/rec_crosstab[1].mean()*100

sns.heatmap(rec_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#referred employees are more likely to be promoted than employees who were recruited through other channels
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='recruitment_channel'>

# %% [markdown]
# ##### >>> Gender x Is promoted

# %%
sns.countplot(x="gender", hue="is_promoted", data=hr_train)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
confusion_matrix = pd.crosstab(hr_train["gender"], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#close to 0, no correlation
# Out:
# 0.011536739288070093

# %%
gen_crosstab = pd.crosstab(hr_train["gender"], hr_train["is_promoted"], normalize='index')
gen_crosstab['idx'] = gen_crosstab[1]/gen_crosstab[1].mean()*100

sns.heatmap(gen_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#female employees are more likely to be promoted than their counterparts
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='gender'>

# %% [markdown]
# ##### >>> KPIs met > 80% x Is promoted

# %%
sns.countplot(x='KPIs_met >80%', hue="is_promoted", data=hr_train)
# Out:
# <AxesSubplot:xlabel='KPIs_met >80%', ylabel='count'>

# %%
confusion_matrix = pd.crosstab(hr_train['KPIs_met >80%'], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#>20% : strong
# Out:
# 0.2214974487082895

# %%
kpi_crosstab = pd.crosstab(hr_train['KPIs_met >80%'], hr_train["is_promoted"], normalize='index')
kpi_crosstab['idx'] = kpi_crosstab[1]/kpi_crosstab[1].mean()*100

sns.heatmap(kpi_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#employees who performed more than 80% of their KPIs are more likely to be promoted
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='KPIs_met >80%'>

# %% [markdown]
# ##### >>> Awards won x Is promoted

# %%
sns.countplot(x='awards_won?', hue="is_promoted", data=hr_train)
# Out:
# <AxesSubplot:xlabel='awards_won?', ylabel='count'>

# %%
confusion_matrix = pd.crosstab(hr_train['awards_won?'], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#>15% : strong
# Out:
# 0.19716332989295685

# %%
awa_crosstab = pd.crosstab(hr_train['awards_won?'], hr_train["is_promoted"], normalize='index')
awa_crosstab['idx'] = awa_crosstab[1]/awa_crosstab[1].mean()*100

sns.heatmap(awa_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#employees who were awarded are more likely to be promoted
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='awards_won?'>

# %% [markdown]
# ##### >>> Previous year rating x Is promoted

# %%
sns.countplot(x="previous_year_rating", hue="is_promoted", data=hr_train)

#, order=hr_train["previous_year_rating"].value_counts().index
# Out:
# <AxesSubplot:xlabel='previous_year_rating', ylabel='count'>

# %%
confusion_matrix = pd.crosstab(hr_train["previous_year_rating"], hr_train["is_promoted"]).values
cramers_v(confusion_matrix)

#>15% : strong
# Out:
# 0.1697543869748982

# %%
rat_crosstab = pd.crosstab(hr_train["previous_year_rating"], hr_train["is_promoted"], normalize='index')
rat_crosstab['idx'] = rat_crosstab[1]/rat_crosstab[1].mean()*100

sns.heatmap(rat_crosstab.sort_values(by='idx', ascending=False), cmap="YlGnBu", annot=True, square=True, vmin=-1, vmax=1)

#employees whose previous year rating were the highest (4 or 5/5) are more likely to be promoted
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='previous_year_rating'>

# %% [markdown]
# ### > Multivaried analysis - between independant features (2/2)

# %% [markdown]
# ##### >>> Nb of trainings

# %%
sns.countplot(x="no_of_trainings", hue="gender", data=hr_train)
# Out:
# <AxesSubplot:xlabel='no_of_trainings', ylabel='count'>

# %%
sns.barplot(x="gender", y="no_of_trainings", data=hr_train)

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='gender', ylabel='no_of_trainings'>

# %%
sns.lineplot(x="age", y="no_of_trainings", data=hr_train)
# Out:
# <AxesSubplot:xlabel='age', ylabel='no_of_trainings'>

# %%
sns.scatterplot(x="age", y="no_of_trainings", data=hr_train)
# Out:
# <AxesSubplot:xlabel='age', ylabel='no_of_trainings'>

# %%
sns.lineplot(x="length_of_service", y="no_of_trainings", data=hr_train)
# Out:
# <AxesSubplot:xlabel='length_of_service', ylabel='no_of_trainings'>

# %%
sns.scatterplot(x="length_of_service", y="no_of_trainings", data=hr_train)
# Out:
# <AxesSubplot:xlabel='length_of_service', ylabel='no_of_trainings'>

# %%
ax = sns.barplot(x="department", y="no_of_trainings", data=hr_train)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

#donne les moyennes ?
# Out:
# [Text(0, 0, 'Sales & Marketing'),
#  Text(1, 0, 'Operations'),
#  Text(2, 0, 'Technology'),
#  Text(3, 0, 'Analytics'),
#  Text(4, 0, 'R&D'),
#  Text(5, 0, 'Procurement'),
#  Text(6, 0, 'Finance'),
#  Text(7, 0, 'HR'),
#  Text(8, 0, 'Legal')]

# %%
sns.barplot(x="no_of_trainings", y="department", data=hr_train, orient="h")

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='no_of_trainings', ylabel='department'>

# %%
#hr_train["no_of_trainings"].value_counts().plot.bar()

# %%
plt.figure(figsize=(10,7))
ax = sns.barplot(x="region", y="no_of_trainings", data=hr_train)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

#donne les moyennes ?
# Out:
# [Text(0, 0, 'region_7'),
#  Text(1, 0, 'region_22'),
#  Text(2, 0, 'region_19'),
#  Text(3, 0, 'region_23'),
#  Text(4, 0, 'region_26'),
#  Text(5, 0, 'region_2'),
#  Text(6, 0, 'region_20'),
#  Text(7, 0, 'region_34'),
#  Text(8, 0, 'region_1'),
#  Text(9, 0, 'region_4'),
#  Text(10, 0, 'region_29'),
#  Text(11, 0, 'region_31'),
#  Text(12, 0, 'region_15'),
#  Text(13, 0, 'region_14'),
#  Text(14, 0, 'region_11'),
#  Text(15, 0, 'region_5'),
#  Text(16, 0, 'region_28'),
#  Text(17, 0, 'region_17'),
#  Text(18, 0, 'region_13'),
#  Text(19, 0, 'region_16'),
#  Text(20, 0, 'region_25'),
#  Text(21, 0, 'region_10'),
#  Text(22, 0, 'region_27'),
#  Text(23, 0, 'region_30'),
#  Text(24, 0, 'region_12'),
#  Text(25, 0, 'region_21'),
#  Text(26, 0, 'region_32'),
#  Text(27, 0, 'region_6'),
#  Text(28, 0, 'region_33'),
#  Text(29, 0, 'region_8'),
#  Text(30, 0, 'region_24'),
#  Text(31, 0, 'region_3'),
#  Text(32, 0, 'region_9'),
#  Text(33, 0, 'region_18')]

# %%
sns.barplot(x="education", y="no_of_trainings", data=hr_train)

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='education', ylabel='no_of_trainings'>

# %%
sns.countplot(hue="no_of_trainings", x="education", data=hr_train)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.countplot(x="no_of_trainings", hue="education", data=hr_train)
# Out:
# <AxesSubplot:xlabel='no_of_trainings', ylabel='count'>

# %%
sns.barplot(x="recruitment_channel", y="no_of_trainings", data=hr_train)

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='recruitment_channel', ylabel='no_of_trainings'>

# %% [markdown]
# ##### >>> Average training score

# %%
sns.barplot(y="avg_training_score", x="gender", data=hr_train)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='avg_training_score'>

# %%
sns.lineplot(x="age", y="avg_training_score", data=hr_train)
# Out:
# <AxesSubplot:xlabel='age', ylabel='avg_training_score'>

# %%
sns.scatterplot(x="length_of_service", y="avg_training_score", data=hr_train)
# Out:
# <AxesSubplot:xlabel='length_of_service', ylabel='avg_training_score'>

# %%
sns.barplot(x="avg_training_score", y="department", data=hr_train, orient="h")

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='avg_training_score', ylabel='department'>

# %%
plt.figure(figsize=(10,7))
ax = sns.barplot(x="region", y="avg_training_score", data=hr_train)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

#donne les moyennes ?
# Out:
# [Text(0, 0, 'region_7'),
#  Text(1, 0, 'region_22'),
#  Text(2, 0, 'region_19'),
#  Text(3, 0, 'region_23'),
#  Text(4, 0, 'region_26'),
#  Text(5, 0, 'region_2'),
#  Text(6, 0, 'region_20'),
#  Text(7, 0, 'region_34'),
#  Text(8, 0, 'region_1'),
#  Text(9, 0, 'region_4'),
#  Text(10, 0, 'region_29'),
#  Text(11, 0, 'region_31'),
#  Text(12, 0, 'region_15'),
#  Text(13, 0, 'region_14'),
#  Text(14, 0, 'region_11'),
#  Text(15, 0, 'region_5'),
#  Text(16, 0, 'region_28'),
#  Text(17, 0, 'region_17'),
#  Text(18, 0, 'region_13'),
#  Text(19, 0, 'region_16'),
#  Text(20, 0, 'region_25'),
#  Text(21, 0, 'region_10'),
#  Text(22, 0, 'region_27'),
#  Text(23, 0, 'region_30'),
#  Text(24, 0, 'region_12'),
#  Text(25, 0, 'region_21'),
#  Text(26, 0, 'region_32'),
#  Text(27, 0, 'region_6'),
#  Text(28, 0, 'region_33'),
#  Text(29, 0, 'region_8'),
#  Text(30, 0, 'region_24'),
#  Text(31, 0, 'region_3'),
#  Text(32, 0, 'region_9'),
#  Text(33, 0, 'region_18')]

# %%
sns.barplot(x="education", y="avg_training_score", data=hr_train)

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.barplot(x="recruitment_channel", y="avg_training_score", data=hr_train)

#donne les moyennes ?
# Out:
# <AxesSubplot:xlabel='recruitment_channel', ylabel='avg_training_score'>

# %%
sns.boxplot(data=hr_train, x=hr_train['is_promoted'], y=hr_train['previous_year_rating'])
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='previous_year_rating'>

# %%
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['awards_won?'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['awards_won?'], shade=True, color="r")

#les distributions ne se superposent pas : corrélation à vérifier
# Out:
# <AxesSubplot:xlabel='awards_won?', ylabel='Density'>

# %%
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['KPIs_met >80%'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['KPIs_met >80%'], shade=True, color="r")

#les distributions ne se superposent pas : corrélation à vérifier
# Out:
# <AxesSubplot:xlabel='KPIs_met >80%', ylabel='Density'>

# %%
sns.kdeplot(hr_train[hr_train['is_promoted'] == 0]['previous_year_rating'], shade=True, color="b")
sns.kdeplot(hr_train[hr_train['is_promoted'] == 1]['previous_year_rating'], shade=True, color="r")

#les distributions ne se superposent pas : corrélation à vérifier
# Out:
# <AxesSubplot:xlabel='previous_year_rating', ylabel='Density'>

# %% [markdown]
# #### Summary - multivaried analysis :
#
# ##### NUMERICAL FEATURES
#
# From graphical analysis, we got :
#
# ** no linear correlation with "is_promoted": confirmed by Pearson correlation table
# - no_of_trainings
# - age
# - length_of_service
#
#
# ** correlation with "is_promoted": but seem rather weak according to Pearson correlation table
# - previous_year_rating : categorial/ordinal ?
# - KPIs_met >80% : categorical/binary ?
# - awards_won? : categorical/binary ?
# - avg_training_score
#
# ##### CATEGORICAL FEATURES
#
# ** no linear correlation :
# - department
# - education
# - gender
# - recruitment_channel
#
# - region : no corr or moderate?

# %%
sns.boxplot(data=hr_train, x=hr_train['is_promoted'], y=hr_train['avg_training_score'])

# %%
sns.boxplot(data=hr_train, x=hr_train['is_promoted'], y=hr_train['length_of_service'])

# %%
sns.boxplot(data=hr_train, x=hr_train['is_promoted'], y=hr_train['age'])

# %%
sns.boxplot(data=hr_train, x=hr_train['is_promoted'], y=hr_train['no_of_trainings'])

# %%
#à revoir

sns.pairplot(hr_train, hue='is_promoted')

# %%
#tip pour la suite : spliter dataset en train plus petit et validation
